# %% [markdown]
# # Term Project Midterm Report

# %% [markdown]
# # 수원, 용인 지역화폐 가맹점  분석

# %% [markdown]
# # 1. 프로젝트 목표 및 내용
#
#  용인시와 수원시의 지역 화폐 가맹점 현황을 모두 받아와 원하는 시군의 가맹점 리스트를 보여주고 업종별로도 선택하여 볼 수 있게 한다. 상호를 입력하였을 시 용인과 수원 중 어느 지역의 지역 화폐가 사용 가능한지를 확인하는 기능도 추가한다. 상호명이 겹치는 경우나 그 이외의 바로 특정할 수 없는 상황에 대한 확인 방법으로 위치 좌표를 받아와 제일 근방에 있는 경우를 출력하도록 한다. 이에 대한 구현이 어려울 경우 전화번호를 이용하는 방법 또는 그 이외의 방법을 이용하여 구하도록 한다.

# %% [markdown]
# # 2. 주제 선정 이유
#
#  현재 코로나 사태로 인하여 경기도에서 경기도민들에게 경기도 재난 기본소득을 지급하였다. 경희대학교 국제캠퍼스 또한 경기도에 위치하여 있고 그로 인해 학교 근처에 거주하고 있는 주소지를 옮긴 학생들도 그 혜택을 받을 수 있게 되었다. 그런데 재난 기본소득은 주민등록상 거주지를 기준으로만 사용할 수 있고 학교의 위치 특성상 횡단보도 하나를 기준으로 용인시와 수원시로 바뀌게 되어 어느 지역의 지역 화폐가 사용 가능한지에 혼동이 올 수 있다. 현재 이를 확인하기 위한 방법으로 경기도에서 제공하는 웹페이지가 있지만 많은 사람이 접속하는 상황 속에서 서버가 다운되거나 느려지는 경우가 잦아 용인과 수원시에 한해서만 가맹점 정보를 받아와 빠르게 확인할 수 있도록 정보를 제공하고자 한다.

# %% [markdown]
# # 3. 데이터 획득
#
# 1. 경기데이터드림 - 지역화폐 가맹점 현황
#  시군코드를 기준으로 가맹점 리스트를 받아오고 상호명과 위도 경도를 이용하여 현재 위치와 가장 가까운 가맹점과 사용 가능한 지역 화폐 명을 Beautiful Soup를 이용하여 파싱한다.
# 2. Google Cloud Platform - Geolocation API
#  현재 위치에 대한 정보를 받아온다.<br>
#  //현재 API key 문제로 현재 위치 받아오는 것이 불가능하여 troubleshooting 기한을 잡고 기한 내 해결 못할 시 다른 방법으로 데이터 획득 혹은 다른 방식으로 변경 후 진행한도록 한다.

# %% [markdown]
# # 4. 데이터의 가공
#
#  받아온 API에서는 XML 형태로 제공이 된다. 이 XML에서 받아온 데이터 중 시군코드를 이용하여 용인시와 수원시의 데이터만 받아올 계획이다. 또한, 이 중 상호명, 업종코드, 업종명(종목명), 사용 가능한 지역화폐, 위도, 경도를 이용하고 만약 위치를 이용한 방법이 안 된다면 전화번호를 이용하여 요구하는 가맹점을 찾아내도록 한다.

# %% [markdown]
# # 5. 획득 데이터 예시

# %% [raw]
# <RegionMnyFacltStus>
# <head>
# <list_total_count>35124</list_total_count>
# <RESULT>
# <CODE>INFO-000</CODE>
# <MESSAGE>정상 처리되었습니다.</MESSAGE>
# </RESULT>
# <api_version>1.0v</api_version>
# </head>
# <row>
# <CMPNM_NM>아로스토(arrosto)</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 수지구 고기동 220번지 지하1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 수지구 고기로 468</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16801</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0577185098</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.3605203365</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>모소밤부</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 수지구 고기동 222-2번지 1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 수지구 고기로 470</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16801</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0576063817</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.3603847101</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>팡팡노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 원삼면 고당리 33-8번지 지하1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 원삼면 고당로15번길 6-1</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17168</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.3109237585</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1643209686</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>전국노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 원삼면 좌항리 412-8번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 원삼면 좌전로 40</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17166</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.3246144998</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2007501328</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>팡팡</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 이동읍 송전리 716-13번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 이동읍 경기동로 683</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17136</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1965974905</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1400696862</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>레이크노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 이동읍 송전리 597-2번지 지하1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 이동읍 경기동로 690</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17136</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1967007693</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1395831846</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>당신의노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 이동읍 송전리 592-14번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 이동읍 경기동로 700</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17136</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1975028092</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1389271987</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>케이팝노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 이동읍 송전리 592-13번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 이동읍 경기동로 698-1</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17136</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1973110054</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1390258651</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>스타노래연습장</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>레저업소-노 래 방</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 이동읍 송전리 597-2번지 지하1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 이동읍 경기동로 690</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17136</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1967007693</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.1395831846</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>씨에스타</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 영덕동 974-3번지 로데오프라자 103호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 흥덕2로117번길 15</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16953</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0723475477</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2779078770</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>모리</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 지곡동 96번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 지삼로250번길 2</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17088</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1360091355</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2363949912</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>지엘씨(GLC)키즈카페</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 지곡동 534-7번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 지삼로 73-4</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17088</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1304385877</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2505026891</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>공주다방</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 67-1번지 B1층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 390</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17064</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1102335618</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2720804585</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>미니펍기흥점</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 63번지 롯데캐슬스카이몰상가 1층 7호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 375</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17064</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1084849387</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2721468001</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>커피베이신갈롯데케슬스카이몰점</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 63번지 1층 3호 롯데케슬스카이몰</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 375</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17064</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1084849387</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2721468001</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>셀렉토커피신갈롯데점</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 63번지 기흥역롯데캐슬스카이 1층 20호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 375</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17064</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1084849387</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2721468001</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>언더브레드/주식회사 에스피푸드</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 63번지 기흥역롯데캐슬스카이 1층 25,26호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 375</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17064</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1084849387</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2721468001</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>카페노아</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 464-6번지</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 325</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17094</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1031326016</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2711374428</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>브라이튼</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 영덕동 1266번지 NS오토허브 A동 1층 14호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 242</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17095</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0931485419</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2694269558</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>2F 카페</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 영덕동 1266번지 NS오토허브 A동 2층 26,27호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 242</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17095</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0931485419</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2694269558</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>윤재석한의원</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>의원-한의원</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 삼가동 250-39번지 인앤인프라자 404호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 중부대로 1154</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17091</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1733243999</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2393342092</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>평강한의원</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>의원-한의원</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 처인구 김량장동 329-6번지 3층</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 처인구 중부대로 1391</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>17049</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1989293288</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2334528108</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>메가커피 (기흥구청점)</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 구갈동 352번지 메가타운 1층 108호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 구갈로 70</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16972</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1116789191</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2805493101</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
#
# """중략"""
#
# <row>
# <CMPNM_NM>카페안</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 165번지 도현마을현대아파트 상가동 102호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 구갈로 115-18</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16962</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1094206861</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2853282838</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>피자에땅</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 구갈동 595-5 강남대프라자111</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 중부대로 579</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16978</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1269688829</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2704127076</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>흙빚는하루</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 신갈동 165번지 도현마을현대 아상가동 103호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 구갈로 115-18</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16962</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1094206861</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2853282838</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>시로드</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 구갈동 353-4번지 신건프라자 701호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 관곡로 92</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16972</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1134954160</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2804831435</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>페리카나치킨</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 고매동 725-2</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR/>
# <REFINE_ZIP_CD>17102</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.0981682679</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2219101885</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# <row>
# <CMPNM_NM>지니엄 ( Xenium )</CMPNM_NM>
# <INDUTYPE_CD/>
# <BIZCOND_NM/>
# <INDUTYPE_NM>일반휴게음식-서양음식</INDUTYPE_NM>
# <TELNO/>
# <REGION_MNY_NM/>
# <BRNHSTRM_MNY_USE_POSBL_YN/>
# <CARD_MNY_USE_POSBL_YN/>
# <MOBILE_MNY_USE_POSBL_YN/>
# <DATA_STD_DE>2019-12-31</DATA_STD_DE>
# <REFINE_LOTNO_ADDR>경기도 용인시 기흥구 구갈동 547-8번지 파크빌 103호</REFINE_LOTNO_ADDR>
# <REFINE_ROADNM_ADDR>경기도 용인시 기흥구 강남서로75번길 2-8</REFINE_ROADNM_ADDR>
# <REFINE_ZIP_CD>16977</REFINE_ZIP_CD>
# <REFINE_WGS84_LOGT>127.1300436374</REFINE_WGS84_LOGT>
# <REFINE_WGS84_LAT>37.2782284463</REFINE_WGS84_LAT>
# <SIGUN_CD>41460</SIGUN_CD>
# <SIGUN_NM>용인시</SIGUN_NM>
# </row>
# </RegionMnyFacltStus>

# %% [markdown]
# # 6. 참고문헌
#
# 1. 경기데이터드림: https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=3NPA52LBMO36CQEQ1GMY28894927&infSeq=1 (지역화폐 가맹점 현황)
# 2. Geolocation API: https://developers.google.com/maps/documentation/geolocation/intro?utm_source=google&utm_medium=cpc&utm_campaign=FY18-Q2-global-demandgen-paidsearchonnetworkhouseads-cs-maps_contactsal_saf&utm_content=text-ad-none-none-DEV_c-CRE_396485512938-ADGP_Hybrid+%7C+AW+SEM+%7C+BKWS+~+Places+%7C+EXA+%7C+Google+Maps+Geolocation+API-KWID_43700049561316526-kwd-300650646226-userloc_1009877&utm_term=KW_google%20geolocation%20api-ST_google+geolocation+api&gclid=EAIaIQobChMIrPytw42h6QIVhmkqCh10EQXNEAAYASAAEgIMnfD_BwE#introduction (Geolocation API-Developer Guide)
# 3. 지역화폐 가맹점 현황_오픈API명세서.xls
# 4. https://velog.io/@yvvyoon/python-current-location-coordinate (Python - 현재 위치 좌표 알아내기)
# 5. https://twpower.github.io/84-how-to-use-beautiful-soup ([Python] Beautiful Soup(뷰티플 수프) 사용법과 예제)

# %% [markdown]
# # 7. 결론
#
#  수원시와 용인시의 가맹점 리스트, 업종명을 통한 분류된 리스트, 상호명 입력받을 경우 현재 위치를 통한 어느 지역 지역 화폐 사용 가능한 지에 대한 정보를 출력하는 프로그램이 완성되어야한다.

# %% [markdown]
# # 8. 프로젝트 계획
#
# 5월 27일 ~ 6월 1일: 현재 위치 파싱(troubleshooting)<br>
# 6월 1일 ~ 6월 12일: 리스트 출력 및 현재 위치와 가맹점 위치 매칭 구현<br>
# 6월 13일 ~ 6월 18일: 예외처리 및 디버깅
